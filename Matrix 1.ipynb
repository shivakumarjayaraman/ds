# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def plotVector(v) :
    plt.plot([0, v[0]], [0, v[1]])

# %%
M = np.array([[2, 3], [2, 1]])
x = np.array([[1, 1.]]).T

plotVector (x.T.reshape(2,))
plotVector(M@x)
